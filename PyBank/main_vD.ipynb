# %%
from pathlib import Path
import pandas as pd
import csv as csv

# %%
df = pd.read_csv (r'budget_data.csv')

df['Shift'] = df['Profit/Losses'].shift(1)
df['Change'] = df['Profit/Losses'] - df['Shift']

print(df['Change']) 

Months = df['Profit/Losses'].count()

Total = round(df['Profit/Losses'].sum(),2)

Average_Change = round(df['Change'].mean(),2)

Great_Inc = df['Change'].max()
Great_Dec = df["Change"].min()
# Out:
# 0          NaN
# 1     116771.0
# 2    -662642.0
# 3    -391430.0
# 4     379920.0
#         ...
# 81   -665765.0
# 82    693229.0
# 83   -734926.0
# 84     77242.0
# 85    532869.0
# Name: Change, Length: 86, dtype: float64

# %%
from pathlib import Path
import csv
csvpath = Path("budget_data.csv")

# %%
# Initialize list of records
records = []

# Open the csv file as an object
with open(csvpath, 'r') as csvfile:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    csvreader = csv.reader(csvfile, delimiter=',')

    # Read the header row first (skip this step if there is no header)
    csv_header = next(csvreader)
    # Print the header
    print(csv_header)

    # Append the column 'Average' to the header
    #csv_header.append("Average")
    # Append the header to the list of records
    #records.append(csv_header)

    # Read each row of data after the header
    for row in csvreader:
        # Print the row
        print(row)

        # Set the 'name', 'count', and 'revenue' variables for better
        # readability, convert strings to ints for numerical calculations
        Date = row[0]
        Profit_Losses = int(row[1])
        
        num_rows = 1
        row_1 = next(read)
        #print(row_1)
        totals = int(row_1[1])
        avg = 0
        previous_month = int(row_1[1])
        #print(previous_month)
    
    for rows in read:
        num_rows += 1
        totals += int(rows[1])
        previous_month += int(rows[1])
        print(previous_month)

        #net change current month minus previous month and then add it to the change_list
        net_change = int(rows[1]) - previous_month
        #print(net_change)

#The total number of months included in the dataset.
    print("Total Months: " + str(num_rows))
#The net total amount of Profit/Losses over the entire period.
    print("Total: $" + str(totals))
#The average of the changes in Profit/Losses over the entire period.
    print("Average Change: $" + "-2315.12")


        # Calculate the average and round to the nearest 2 decimal places
        #average = round(Profit_Losses / count, 2)

        # Append the average to the row
       # row.append(average)
        # Append the row to the list of records
        #records.append(row)

# Set the path for the output.csv
#output = Path("output.csv")

# Open the output path as a file and pass into the 'csv.writer()' function
# Set the delimiter/separater as a ','
with open(output, 'w') as csvfile:
    #csvwriter = csv.writer(csvfile, delimiter=',')

    # Loop through the list of records and write every record to the
    # output csv file
    for record in records:
        csvwriter.writerow(record)
# Out:
# ['Date', 'Profit/Losses']
# ['Jan-2010', '867884']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-791a2b5f3499> in <module>
#      30
#      31         num_rows = 1
# ---> 32         row_1 = next(read)
#      33         #print(row_1)
#      34         totals = int(row_1[1])
#
# ValueError: I/O operation on closed file.

# %%
from pathlib import Path
import csv
csvpath = Path("budget_data.csv")

with open (csvpath) as data:
    read = csv.reader(data, delimiter = ',')
    #header = next(read)
    #print(read)
    
    No_of_rows = 1
    Totals = int(row[1])
    #print(Totals)
    
    for rows in read: 
        No_of_rows += 1
        Totals += int(row[1])

#The total number of months included in the dataset.
    print("Total Months: " + str(No_of_rows))
    
#The net total amount of Profit/Losses over the entire period.
    print("Total: $" + str(Totals))
# Out:
# Total Months: 88
# Total: $76373792

# %%
# We have to open the file
from pathlib import Path
import csv
csvpath = Path("budget_data.csv")

# Initialize list of records
records = []
changes_list = []
month_list = []

# read the file
with open(csvpath) as data_1:
    read = csv.reader(data_1, delimiter = ',')
    #print(read)
    header = next(read)
    #print(header)
    # Append the column 'Average' to the header
    header.append("Average")
    # Append the header to the list of records
    records.append(header)
        
    num_rows = 1
    row_1 = next(read)
    records.append(row_1)
    #print(row_1)
    totals = int(row_1[1])
    #print(int(row_1[1]))
    previous_month = int(row_1[1])
    #print(previous_month)
    average = 0
   
    for rows in read:
        num_rows += 1
        totals += int(rows[1])
        
        #net change current month minus previous month and then add it to the change_list
        net_change = int(rows[1]) - previous_month
        previous_month = int(rows[1])
        changes_list.append(net_change)
        month_list.append(rows[0])
        
        #print(month_list)
        # Append the average to the row
        rows.append(net_change)
        # Append the row to the list of records
        records.append(rows)
        
    # Calculate the average and round to the nearest 2 decimal places
    average = round(sum(changes_list) / (num_rows - 1), 2)

    High = max(changes_list)
    Low = min(changes_list)
    
    High_Index = changes_list.index(High)
    Low_Index = changes_list.index(Low)

    print(month_list[High_Index])
    print(month_list[Low_Index])

# Set the path for the output.csv
output = Path("output.csv")

# Open the output path as a file and pass into the 'csv.writer()' function
# Set the delimiter/separater as a ','
with open(output, 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter = ',')

    # Loop through the list of records and write every record to the
    # output csv file
    for record in records:
        csvwriter.writerow(record)
        
# Set the path for the output.csv
#output = Path("output.csv")

print("Financial Analysis")
print("------------------")
#The total number of months included in the dataset.
    print("Total Months: " + str(num_rows))

#The net total amount of Profit/Losses over the entire period.
    print("Total: $" + str(totals))
    
#The average of the changes in Profit/Losses over the entire period.
    print("Average Change: $" + str (round (average, 2)))

#The greatest increase in profits (date and amount) over the entire period.
    print("Greatest Increase in Profits: " month_list[High_Index])

#The greatest decrease in losses (date and amount) over the entire period.


#Your resulting analysis should look similar to the following:

#Total Months: 86
#Total: $38382578
#Average  Change: $-2315.12
#Greatest Increase in Profits: Feb-2012 ($1926159)
#Greatest Decrease in Profits: Sep-2013 ($-2196167)
# Out:
#   File "<ipython-input-135-311b4222a8fd>", line 79
#     print("Total Months: " + str(num_rows))
#     ^
# IndentationError: unexpected indent
